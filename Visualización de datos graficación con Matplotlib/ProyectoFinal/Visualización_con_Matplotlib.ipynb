# %% [markdown]
# # Aula01

# %% [markdown]
# ##Primeras Visualizaciones

# %%
import pandas as pd
df = pd.read_csv('base_tiempo.csv')
df.head()
# Out:
#    temperatura  presión  humedad  dirección del viento  velocidad del viento  \
# 0   282.080000   1024.0     81.0                   0.0                   0.0
# 1   282.080000   1024.0     81.0                   0.0                   0.0
# 2   282.083252   1024.0     80.0                   4.0                   0.0
# 3   282.091866   1024.0     80.0                  18.0                   0.0
# 4   282.100481   1024.0     80.0                  31.0                   0.0
#
#   dia_de_semana                fecha
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df['date'] = pd.to_datetime(df['fecha'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   temperatura           45253 non-null  float64
#  1   presión               45253 non-null  float64
#  2   humedad               45253 non-null  float64
#  3   dirección del viento  45253 non-null  float64
#  4   velocidad del viento  45253 non-null  float64
#  5   dia_de_semana         45253 non-null  object
#  6   fecha                 45253 non-null  object
#  7   date                  45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 2.8+ MB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(df['date'], df['temperatura'])

# %%
plt.figure(figsize=(15,8))
plt.plot(df['date'], df['temperatura'])

# %%
plt.figure(figsize=(15,8))
plt.plot(df['date'], df['temperatura'])
plt.title('Temperatura en el tiempo')
# Out:
# Text(0.5, 1.0, 'Temperatura en el tiempo')

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'])
eje.set_title('Temperatura en el tiempo')
# Out:
# Text(0.5, 1.0, 'Temperatura en el tiempo')

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'])
eje.set_title('Temperatura en el tiempo')
eje.set_ylabel('Temperatura')
eje.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'])
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'])
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'green')
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %% [markdown]
# # Aula02

# %% [markdown]
# ##Personalizando nuestras visualizaciones

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'g', lw = 4)
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'g', lw = 0.4)
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'g', ls = 'dotted')
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %%
import datetime
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'g', marker = 'o')
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en el tiempo', fontsize=25)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)
eje.legend(['temperatura'], loc = 'lower right', fontsize=15)
eje.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20)
eje.legend(['temperatura'], loc='best', fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20)
eje.legend(['temperatura'], loc='best', fontsize=15)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)

eje2.plot(df['date'], df['temperatura'], color = 'b')
eje2.set_title('Temperatura en el tiempo', fontsize=15)
eje2.legend(['temperatura'], loc='best', fontsize=8)
eje2.set_ylabel('Temperatura', fontsize=10)
eje2.set_xlabel('Date', fontsize=10)
# Out:
# Text(0.5, 0, 'Date')

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en 2014', fontsize=25, pad=20)
eje.legend(['temperatura'], loc='lower right', fontsize=15)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)

eje2.plot(df['date'], df['temperatura'], color = 'b')
eje2.set_title('Temperatura en el tiempo', fontsize=15)
eje2.legend(['temperatura'], loc='best', fontsize=8)
eje2.set_ylabel('Temperatura', fontsize=10)
eje2.set_xlabel('Date', fontsize=10)
eje2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eje.set_title('Temperatura en Mayo 2014', fontsize=25, pad=20)
eje.legend(['temperatura'], loc='lower right', fontsize=15)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)

eje2.plot(df['date'], df['temperatura'], color = 'b')
eje2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje2.set_title('Temperatura en 2014', fontsize=15)
eje2.legend(['temperatura'], loc='best', fontsize=8)
eje2.set_ylabel('Temperatura', fontsize=10)
eje2.set_xlabel('Date', fontsize=10)
eje2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0, 0, 1, 1])
eje2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eje.grid(True)
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eje.set_ylim(270, 320)
eje.set_title('Temperatura en Mayo 2014', fontsize=25, pad=20)
eje.legend(['temperatura'], loc='lower right', fontsize=15)
eje.set_ylabel('Temperatura', fontsize=20)
eje.set_xlabel('Date', fontsize=20)

azul_izquierda = df['date'] < datetime.datetime(2014,5,1)
azul_derecha = df['date'] > datetime.datetime(2014,6,1)

eje2.plot(df['date'], df['temperatura'], color = 'g')
eje2.plot(df[azul_izquierda]['date'],df[azul_izquierda]['temperatura'], color = 'b')
eje2.plot(df[azul_derecha]['date'],df[azul_derecha]['temperatura'], color = 'b')
eje2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje2.set_title('Temperatura en 2014', fontsize=15)
eje2.legend(['temperatura'], loc='best', fontsize=8)
eje2.set_ylabel('Temperatura', fontsize=10)
eje2.set_xlabel('Date', fontsize=10)
eje2.grid(True)

# %% [markdown]
# # Aula03

# %% [markdown]
# #Anotaciones y otros gráficos

# %%
fig = plt.figure(figsize = (15,8))
eje = fig.add_axes([0,0,1,1])
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20)
eje.set_xlabel('Date', fontsize=20)
eje.set_ylabel('Temperatura', fontsize=20)
eje.legend(['Temperatura'], loc='lower right', fontsize=15)
eje.grid(True)
eje.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eje.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
fig = plt.figure(figsize = (15,8))
eje = fig.add_axes([0,0,1,1])
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20)
eje.set_xlabel('Date', fontsize=20)
eje.set_ylabel('Temperatura', fontsize=20)
eje.legend(['Temperatura'], loc='lower right', fontsize=15)
eje.grid(True)
x1 = df['date'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])
eje.annotate("Máximo", xy=(x1,y1), fontsize=20)
eje.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eje.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
fig = plt.figure(figsize = (15,8))
eje = fig.add_axes([0,0,1,1])
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20)
eje.set_xlabel('Date', fontsize=20)
eje.set_ylabel('Temperatura', fontsize=20)
eje.legend(['Temperatura'], loc='lower right', fontsize=15)
eje.grid(True)
x1 = df['date'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])
x2 = df['date'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5
eje.annotate("Máximo", xy=(x1,y1), fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
eje.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eje.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
fig = plt.figure(figsize = (15,8))
eje = fig.add_axes([0,0,1,1])
eje.plot(df['date'], df['temperatura'], color = 'g')
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20)
eje.set_xlabel('Date', fontsize=20)
eje.set_ylabel('Temperatura', fontsize=20)
eje.legend(['Temperatura'], loc='lower right', fontsize=15)
eje.grid(True)
x1 = df['date'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])
x2 = df['date'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5
eje.annotate("Máximo", xy=(x1,y1), fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
x1 = df['date'][df['temperatura'].idxmin()]
y1 = min(df['temperatura'])
x2 = df['date'][df['temperatura'].idxmin() - 7000]
y2 = min(df['temperatura']) + 5
eje.annotate("Mínimo", xy=(x1,y1), fontsize=20,xytext=(x2,y2), arrowprops=dict(facecolor='k'))
eje.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eje.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
temperatura_por_dia_de_semana = df.groupby('dia_de_semana')['temperatura'].mean()
nombre_dias = ['Domingo', 'Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado']
temperatura_por_dia_de_semana = temperatura_por_dia_de_semana[nombre_dias]
temperatura_por_dia_de_semana
# Out:
# dia_de_semana
# Domingo      285.009095
# Lunes        284.985382
# Martes       284.892811
# Miercoles    284.998290
# Jueves       285.000643
# Viernes      285.060886
# Sabado       285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_de_semana))

eje.bar(indice, temperatura_por_dia_de_semana)
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
eje.set_xlabel('Dia de semana', fontsize=15)
eje.set_ylabel('Temperatura promedio', fontsize=15)
# Out:
# Text(0, 0.5, 'Temperatura promedio')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_de_semana))

eje.bar(indice, temperatura_por_dia_de_semana)
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
eje.set_xlabel('Dia de semana', fontsize=15)
eje.set_ylabel('Temperatura promedio', fontsize=15)
eje.set_xticks(indice)
eje.set_xticklabels(nombre_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Lunes'),
#  Text(0, 0, 'Martes'),
#  Text(0, 0, 'Miercoles'),
#  Text(0, 0, 'Jueves'),
#  Text(0, 0, 'Viernes'),
#  Text(0, 0, 'Sabado')]

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_de_semana))
colores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']
eje.bar(indice, temperatura_por_dia_de_semana, color=colores)
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
eje.set_xlabel('Dia de semana', fontsize=15)
eje.set_ylabel('Temperatura promedio', fontsize=15)
eje.set_xticks(indice)
eje.set_xticklabels(nombre_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Lunes'),
#  Text(0, 0, 'Martes'),
#  Text(0, 0, 'Miercoles'),
#  Text(0, 0, 'Jueves'),
#  Text(0, 0, 'Viernes'),
#  Text(0, 0, 'Sabado')]

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_de_semana))
colores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']
eje.bar(indice, temperatura_por_dia_de_semana, color=colores, edgecolor='black')
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
eje.set_xlabel('Dia de semana', fontsize=15)
eje.set_ylabel('Temperatura promedio', fontsize=15)
eje.set_xticks(indice)
eje.set_xticklabels(nombre_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Lunes'),
#  Text(0, 0, 'Martes'),
#  Text(0, 0, 'Miercoles'),
#  Text(0, 0, 'Jueves'),
#  Text(0, 0, 'Viernes'),
#  Text(0, 0, 'Sabado')]

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
eje.pie(temperatura_por_dia_de_semana, labels=temperatura_por_dia_de_semana.index)
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia de semana')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
eje.pie(temperatura_por_dia_de_semana, labels=temperatura_por_dia_de_semana.index, autopct='%.1f%%')
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia de semana')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]
eje.pie(temperatura_por_dia_de_semana, labels=temperatura_por_dia_de_semana.index, autopct='%.1f%%', explode=explodir)
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia de semana')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]
eje.pie(temperatura_por_dia_de_semana, labels=temperatura_por_dia_de_semana.index, autopct='%.1f%%', explode=explodir, shadow=True)
eje.set_title('Temperatura por dia de semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia de semana')

# %% [markdown]
# # Aula04

# %% [markdown]
# ##Gráficos de dispersión

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1])
eje.scatter(df['SepalLengthCm'], df['SepalWidthCm'])
eje.set_title('Gráfico de dispersión', fontsize=25, pad=15)
eje.set_xlabel('SepalLengthCm', fontsize=15)
eje.set_ylabel('SepalWidthCm', fontsize=15)
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1])
eje.scatter(df['SepalLengthCm'], df['SepalWidthCm'])
eje.set_title('Gráfico de dispersión', fontsize=25, pad=15)
eje.set_xlabel('SepalLengthCm', fontsize=15)
eje.set_ylabel('SepalWidthCm', fontsize=15)
eje.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1])
colores = {'Iris-setosa': 'r', 'Iris-versicolor': 'b', 'Iris-virginica': 'g'}
for especie in df['Species'].unique():
    tmp = df[df['Species'] == especie]
    eje.scatter(tmp['SepalLengthCm'], tmp['SepalWidthCm'],color=colores[especie])

eje.set_title('Gráfico de dispersión', fontsize=25, pad=15)
eje.set_xlabel('SepalLengthCm', fontsize=15)
eje.set_ylabel('SepalWidthCm', fontsize=15)
eje.tick_params(labelsize=15)
eje.legend(colores, fontsize=20)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1])
colores = {'Iris-setosa': 'r', 'Iris-versicolor': 'b', 'Iris-virginica': 'g'}
marcadores = {'Iris-setosa': 'x', 'Iris-versicolor': 'o', 'Iris-virginica': 'v'}
for especie in df['Species'].unique():
    tmp = df[df['Species'] == especie]
    eje.scatter(tmp['SepalLengthCm'], tmp['SepalWidthCm'], color=colores[especie], marker=marcadores[especie])

eje.set_title('Gráfico de dispersión', fontsize=25, pad=15)
eje.set_xlabel('SepalLengthCm', fontsize=15)
eje.set_ylabel('SepalWidthCm', fontsize=15)
eje.tick_params(labelsize=15)
eje.legend(colores, fontsize=20)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1])
colores = {'Iris-setosa': 'r', 'Iris-versicolor': 'b', 'Iris-virginica': 'g'}
marcadores = {'Iris-setosa': 'x', 'Iris-versicolor': 'o', 'Iris-virginica': 'v'}
for especie in df['Species'].unique():
    tmp = df[df['Species'] == especie]
    eje.scatter(tmp['SepalLengthCm'], tmp['SepalWidthCm'], color=colores[especie], marker=marcadores[especie], s=100)

eje.set_title('Gráfico de dispersión', fontsize=25, pad=15)
eje.set_xlabel('SepalLengthCm', fontsize=15)
eje.set_ylabel('SepalWidthCm', fontsize=15)
eje.tick_params(labelsize=15)
eje.legend(colores, fontsize=20)

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
eje.boxplot(df['PetalWidthCm'])
eje.set_title('Gráfico de caja', fontsize=15, pad=10)
eje.set_xticklabels(['PetalWidthCm'])
# Out:
# [Text(0, 0, 'PetalWidthCm')]

# %%
fig = plt.figure(figsize=(8,5))
eje = fig.add_axes([0,0,1,1])
eje.boxplot(df.drop('Species', axis=1).values)
eje.set_title('Gráfico de caja', fontsize=15, pad=10)
eje.set_xticklabels(df.drop('Species', axis=1).columns)
# Out:
# [Text(0, 0, 'SepalLengthCm'),
#  Text(0, 0, 'SepalWidthCm'),
#  Text(0, 0, 'PetalLengthCm'),
#  Text(0, 0, 'PetalWidthCm')]

# %%
fig = plt.figure(figsize=(8,5))
eje = fig.add_axes([0,0,1,1])
eje.boxplot(df.drop('Species', axis=1).values, patch_artist=True)
eje.set_title('Gráfico de caja', fontsize=15, pad=10)
eje.set_xticklabels(df.drop('Species', axis=1).columns)
# Out:
# [Text(0, 0, 'SepalLengthCm'),
#  Text(0, 0, 'SepalWidthCm'),
#  Text(0, 0, 'PetalLengthCm'),
#  Text(0, 0, 'PetalWidthCm')]

# %%
fig = plt.figure(figsize=(8,5))
eje = fig.add_axes([0,0,1,1])
colores = ['red', 'blue', 'orange', 'green']
cajas = eje.boxplot(df.drop('Species', axis=1).values, patch_artist=True)
eje.set_title('Gráfico de caja', fontsize=15, pad=10)
eje.set_xticklabels(df.drop('Species', axis=1).columns)
for caja, color in zip(cajas['boxes'], colores):
    caja.set(color=color)

# %%
fig = plt.figure(figsize=(8,5))
eje = fig.add_axes([0,0,1,1])
colores = ['red', 'blue', 'orange', 'green']
cajas = eje.boxplot(df.drop('Species', axis=1).values, patch_artist=True)
eje.set_title('Gráfico de caja', fontsize=15, pad=10)
eje.set_xticklabels(df.drop('Species', axis=1).columns)

for caja, color in zip(cajas['boxes'], colores):
    caja.set(color=color)

for outlier in cajas['fliers']:
    outlier.set(marker='x', markersize=8)

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])

eje.hist(df['PetalLengthCm'])
eje.set_title('Histograma', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])

eje.hist(df['PetalLengthCm'], bins=20)
eje.set_title('Histograma', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])

eje.hist(df['PetalLengthCm'], bins=20, density=True)
eje.set_title('Histograma', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
mu, sigma = df['PetalLengthCm'].mean(), df['PetalLengthCm'].std()
eje.hist(df['PetalLengthCm'], bins=20)
eje.set_title('Histograma', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)
eje.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma), xy=(4.5, 20), fontsize=20)
# Out:
# Text(4.5, 20, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
mu, sigma = df['PetalLengthCm'].mean(), df['PetalLengthCm'].std()
eje.hist(df['PetalLengthCm'], bins=20)
eje.set_title('Histograma', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)
eje.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma), xy=(4.5, 20), fontsize=20)
eje.axvline(mu, color = 'k', linestyle='--')
eje.annotate('promedio', xy=(mu-1.3, 28), fontsize=20)
# Out:
# Text(2.458666666666666, 28, 'promedio')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
mu, sigma = df['PetalLengthCm'].mean(), df['PetalLengthCm'].std()
eje.hist(df['PetalLengthCm'], bins=20)
eje.set_title('Histograma', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)
eje.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma), xy=(4.5, 20), fontsize=20)
eje.axvline(mu, color = 'k', linestyle='--')
eje.annotate('promedio', xy=(mu-1.3, 28), fontsize=20)
eje.axvline(df['PetalLengthCm'].median(), color='g', linestyle='--')
eje.annotate('mediana', xy=(df['PetalLengthCm'].median(), 31), fontsize=20)
# Out:
# Text(4.35, 31, 'mediana')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
df_iv = df[df['Species'] == 'Iris-versicolor']
mu, sigma = df_iv['PetalLengthCm'].mean(), df_iv['PetalLengthCm'].std()
eje.hist(df_iv['PetalLengthCm'], bins=20)
eje.set_title('Iris Versicolor', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)
eje.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma), xy=(4.6, 6), fontsize=20)
eje.axvline(mu, color = 'k', linestyle='--')
eje.annotate('promedio', xy=(mu-0.5, 5.5), fontsize=20)
eje.axvline(df_iv['PetalLengthCm'].median(), color='g', linestyle='--')
eje.annotate('mediana', xy=(df_iv['PetalLengthCm'].median()-0.7, 6.5), fontsize=20, color='g')
fig.savefig('histograma_iv.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
df_is = df[df['Species'] == 'Iris-setosa']
mu, sigma = df_is['PetalLengthCm'].mean(), df_is['PetalLengthCm'].std()
eje.hist(df_is['PetalLengthCm'], bins=20)
eje.set_title('Iris Setosa', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)
eje.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma), xy=(1.7, 7), fontsize=20)
eje.axvline(mu, color = 'k', linestyle='--')
eje.annotate('promedio', xy=(mu-0.2, 13.5), fontsize=20)
eje.axvline(df_is['PetalLengthCm'].median(), color='g', linestyle='--')
eje.annotate('mediana', xy=(df_is['PetalLengthCm'].median()+0.05, 12), fontsize=20, color='g')
fig.savefig('histograma_is.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eje = fig.add_axes([0,0,1,1])
df_ivc = df[df['Species'] == 'Iris-virginica']
mu, sigma = df_ivc['PetalLengthCm'].mean(), df_ivc['PetalLengthCm'].std()
eje.hist(df_ivc['PetalLengthCm'], bins=20)
eje.set_title('Iris Virginica', fontsize=15, pad=10)
eje.set_xlabel('PetalLengthCm', fontsize=15)
eje.grid(True)
eje.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma), xy=(6.3, 7), fontsize=20)
eje.axvline(mu, color = 'k', linestyle='--')
eje.annotate('promedio', xy=(mu, 8), fontsize=20)
eje.axvline(df_ivc['PetalLengthCm'].median(), color='g', linestyle='--')
eje.annotate('mediana', xy=(df_ivc['PetalLengthCm'].median(), 7), fontsize=20, color='g')
fig.savefig('histograma_ivg.png', bbox_inches='tight')

# %%
from PIL import Image

ancho, altura = Image.open('histograma_ivg.png').size
combinada = Image.new("RGB", (3*ancho, altura))
intervalo = 0
for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png',
                               'histograma_ivg.png']):
    combinada.paste(imagem, (intervalo, 0))
    intervalo += ancho
    
combinada.save('combinada.png')
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1176x360 at 0x7FEBE54D7BD0>
